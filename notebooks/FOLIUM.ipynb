# %%
import pandas as pd
import folium
from folium import plugins
import os
import json

# %%
latvijas_universitate = folium.Map(location=[56.95080,24.11650],
                    zoom_start = 16)
latvijas_universitate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_799584221d6b884a68f7712d51c66eac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_799584221d6b884a68f7712d51c66eac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_799584221d6b884a68f7712d51c66eac = L.map(
#                 &quot;map_799584221d6b884a68f7712d51c66eac&quot;,
#                 {
#                     center: [56.9508, 24.1165],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a8c9ab999765bcc41a2c0b87d265a15 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_799584221d6b884a68f7712d51c66eac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latvijas_universitate = folium.Map(location=[56.95080,24.11650],
                        tiles = "Stamen Terrain",
                        zoom_start = 15)
latvijas_universitate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91aad399c38eea9b775c98777c6607c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91aad399c38eea9b775c98777c6607c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91aad399c38eea9b775c98777c6607c3 = L.map(
#                 &quot;map_91aad399c38eea9b775c98777c6607c3&quot;,
#                 {
#                     center: [56.9508, 24.1165],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_948510741b2c959625d8ce07fa3070b7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91aad399c38eea9b775c98777c6607c3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latvijas_universitate = folium.Map(location=[56.95080,24.11650],
                        tiles = "Stamen Toner",
                        zoom_start = 20)
latvijas_universitate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a074469249edd0a31bfea0a43fb80def {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a074469249edd0a31bfea0a43fb80def&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a074469249edd0a31bfea0a43fb80def = L.map(
#                 &quot;map_a074469249edd0a31bfea0a43fb80def&quot;,
#                 {
#                     center: [56.9508, 24.1165],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8aa0c6c432000a8f301666f866783fb = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a074469249edd0a31bfea0a43fb80def);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latvijas_universitate = folium.Map(location=[56.95080,24.11650],
                        width=500, height=500, #var nodefinēt dimensijas
                        zoom_start = 20)

latvijas_universitate

folium.Marker([56.95080,24.11650], popup='Latvijas universitāte').add_to(latvijas_universitate)
latvijas_universitate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dfb5e19d4447cc6319e5aa8cf874a66 {
#                     position: relative;
#                     width: 500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dfb5e19d4447cc6319e5aa8cf874a66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dfb5e19d4447cc6319e5aa8cf874a66 = L.map(
#                 &quot;map_4dfb5e19d4447cc6319e5aa8cf874a66&quot;,
#                 {
#                     center: [56.9508, 24.1165],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_824ac64022a46bc7378c78c5c64cafc9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4dfb5e19d4447cc6319e5aa8cf874a66);
#
#
#             var marker_aa3526f569a9c6e55bd04a49ddc82197 = L.marker(
#                 [56.9508, 24.1165],
#                 {}
#             ).addTo(map_4dfb5e19d4447cc6319e5aa8cf874a66);
#
#
#         var popup_3febab70ab3270c9b149dd2ddc917bfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_177c7b8a20c64f4c40afa04494144338 = $(`&lt;div id=&quot;html_177c7b8a20c64f4c40afa04494144338&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latvijas universitāte&lt;/div&gt;`)[0];
#                 popup_3febab70ab3270c9b149dd2ddc917bfa.setContent(html_177c7b8a20c64f4c40afa04494144338);
#
#
#
#         marker_aa3526f569a9c6e55bd04a49ddc82197.bindPopup(popup_3febab70ab3270c9b149dd2ddc917bfa)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latvijas_universitate = folium.Map(location=[56.9504,24.11650],
                        #tiles = "Stamen Watercolor",
                        zoom_start = 20)
# Parasts marķieris, zaļš
folium.Marker([56.95080,24.11650],
              popup='Latvijas universitāte',
              icon=folium.Icon(color='green')
             ).add_to(latvijas_universitate)

# Apaļš marķieris
folium.CircleMarker([56.95,24.1174],
                    radius=100,
                    popup='Mūzikas akadēmija',
                    color='red',
                    ).add_to(latvijas_universitate)

# Interactive marker
latvijas_universitate.add_child(folium.ClickForMarker(popup="Galapunkts"))

latvijas_universitate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3499e74cd5359bf22f7d6ca8c1073f6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3499e74cd5359bf22f7d6ca8c1073f6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3499e74cd5359bf22f7d6ca8c1073f6a = L.map(
#                 &quot;map_3499e74cd5359bf22f7d6ca8c1073f6a&quot;,
#                 {
#                     center: [56.9504, 24.1165],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01f570d203ef060a2a65ecf995a87475 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3499e74cd5359bf22f7d6ca8c1073f6a);
#
#
#             var marker_e43d0fdb6d4aa6ec6392a1f8cc5325fe = L.marker(
#                 [56.9508, 24.1165],
#                 {}
#             ).addTo(map_3499e74cd5359bf22f7d6ca8c1073f6a);
#
#
#             var icon_43d78bb601c7024183cc383994444c46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e43d0fdb6d4aa6ec6392a1f8cc5325fe.setIcon(icon_43d78bb601c7024183cc383994444c46);
#
#
#         var popup_1ad6b26b7d23cc0cf2a3145750575975 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f70b59cc353d893db7e9bed9a0d65844 = $(`&lt;div id=&quot;html_f70b59cc353d893db7e9bed9a0d65844&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latvijas universitāte&lt;/div&gt;`)[0];
#                 popup_1ad6b26b7d23cc0cf2a3145750575975.setContent(html_f70b59cc353d893db7e9bed9a0d65844);
#
#
#
#         marker_e43d0fdb6d4aa6ec6392a1f8cc5325fe.bindPopup(popup_1ad6b26b7d23cc0cf2a3145750575975)
#         ;
#
#
#
#
#             var circle_marker_0b23338f36d64b82f1b42b2c7afd4678 = L.circleMarker(
#                 [56.95, 24.1174],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3499e74cd5359bf22f7d6ca8c1073f6a);
#
#
#         var popup_68fb5719084329c9ba3f0f7b86da270e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0919089419cc1adb9eb2706a90b9a5d5 = $(`&lt;div id=&quot;html_0919089419cc1adb9eb2706a90b9a5d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mūzikas akadēmija&lt;/div&gt;`)[0];
#                 popup_68fb5719084329c9ba3f0f7b86da270e.setContent(html_0919089419cc1adb9eb2706a90b9a5d5);
#
#
#
#         circle_marker_0b23338f36d64b82f1b42b2c7afd4678.bindPopup(popup_68fb5719084329c9ba3f0f7b86da270e)
#         ;
#
#
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_3499e74cd5359bf22f7d6ca8c1073f6a);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_3499e74cd5359bf22f7d6ca8c1073f6a.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`Galapunkts`);
#                     };
#                 map_3499e74cd5359bf22f7d6ca8c1073f6a.on(&#x27;click&#x27;, newMarker);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
centrs = folium.Map(location=[56.9514934,24.1135],
                        tiles = "Stamen Toner", #Mapbox Bright
                        zoom_start = 17)

folium.Marker([56.9514934,24.1135],
              popup='Brīvības piemineklis',
              icon=folium.Icon(color='green')
             ).add_to(centrs)
folium.Marker([56.95080,24.11650], 
              popup='Latvijas Universitāte',
              icon=folium.Icon(color='blue',icon='university', prefix='fa') 
             ).add_to(centrs)

folium.Marker([56.9514934,24.1111156], 
              popup='Bastejkalns',
              icon=folium.Icon(color='red',icon='bicycle', prefix='fa')
             ).add_to(centrs)

centrs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b81249bd735762ddad9edee60f1b9d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b81249bd735762ddad9edee60f1b9d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b81249bd735762ddad9edee60f1b9d5 = L.map(
#                 &quot;map_7b81249bd735762ddad9edee60f1b9d5&quot;,
#                 {
#                     center: [56.9514934, 24.1135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_baced0a4d1a2de9ca79840ac39392b8d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7b81249bd735762ddad9edee60f1b9d5);
#
#
#             var marker_d37fe74f2664871918fc01d047f07106 = L.marker(
#                 [56.9514934, 24.1135],
#                 {}
#             ).addTo(map_7b81249bd735762ddad9edee60f1b9d5);
#
#
#             var icon_65866a17ec4d182e74d9f7bb650ef0d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d37fe74f2664871918fc01d047f07106.setIcon(icon_65866a17ec4d182e74d9f7bb650ef0d7);
#
#
#         var popup_a7b01041c3bd3f3810e52dd032c58402 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26c0d99d3cfa30ac4888eec68b9d450b = $(`&lt;div id=&quot;html_26c0d99d3cfa30ac4888eec68b9d450b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brīvības piemineklis&lt;/div&gt;`)[0];
#                 popup_a7b01041c3bd3f3810e52dd032c58402.setContent(html_26c0d99d3cfa30ac4888eec68b9d450b);
#
#
#
#         marker_d37fe74f2664871918fc01d047f07106.bindPopup(popup_a7b01041c3bd3f3810e52dd032c58402)
#         ;
#
#
#
#
#             var marker_2a6763ecc85bb045f7e215e65ab4ee2f = L.marker(
#                 [56.9508, 24.1165],
#                 {}
#             ).addTo(map_7b81249bd735762ddad9edee60f1b9d5);
#
#
#             var icon_c0da97ab89068c60d4bdfc701f5067f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2a6763ecc85bb045f7e215e65ab4ee2f.setIcon(icon_c0da97ab89068c60d4bdfc701f5067f3);
#
#
#         var popup_6db67c61a36b896bf778d1155256e6bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd84846d32119c762b829a736b97cede = $(`&lt;div id=&quot;html_fd84846d32119c762b829a736b97cede&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latvijas Universitāte&lt;/div&gt;`)[0];
#                 popup_6db67c61a36b896bf778d1155256e6bf.setContent(html_fd84846d32119c762b829a736b97cede);
#
#
#
#         marker_2a6763ecc85bb045f7e215e65ab4ee2f.bindPopup(popup_6db67c61a36b896bf778d1155256e6bf)
#         ;
#
#
#
#
#             var marker_0f9a386a270d64f8a8c9c276257d07d4 = L.marker(
#                 [56.9514934, 24.1111156],
#                 {}
#             ).addTo(map_7b81249bd735762ddad9edee60f1b9d5);
#
#
#             var icon_bfdae2632cffccfce4fa5e190a1b5093 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0f9a386a270d64f8a8c9c276257d07d4.setIcon(icon_bfdae2632cffccfce4fa5e190a1b5093);
#
#
#         var popup_1097017a430e02532253a7f551cac248 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a47f741b9f027df1db679ccc772ea123 = $(`&lt;div id=&quot;html_a47f741b9f027df1db679ccc772ea123&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bastejkalns&lt;/div&gt;`)[0];
#                 popup_1097017a430e02532253a7f551cac248.setContent(html_a47f741b9f027df1db679ccc772ea123);
#
#
#
#         marker_0f9a386a270d64f8a8c9c276257d07d4.bindPopup(popup_1097017a430e02532253a7f551cac248)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;"

# %%
from folium.plugins import MiniMap

latvia = folium.Map(location=(57,25), zoom_start=6,width=500, height=500)

minimap = MiniMap()
latvia.add_child(minimap)
latvia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08332529dbc2c4ac62b553ef10db54d6 {
#                     position: relative;
#                     width: 500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08332529dbc2c4ac62b553ef10db54d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08332529dbc2c4ac62b553ef10db54d6 = L.map(
#                 &quot;map_08332529dbc2c4ac62b553ef10db54d6&quot;,
#                 {
#                     center: [57.0, 25.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e4bf3014e6dc9548877f99fa56824ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_08332529dbc2c4ac62b553ef10db54d6);
#
#
#             var tile_layer_2f3999198b7cf4edc601b94be985c7bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_bf64a54f1afb5ecac53d25bb987df0f1 = new L.Control.MiniMap(
#                 tile_layer_2f3999198b7cf4edc601b94be985c7bc,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_08332529dbc2c4ac62b553ef10db54d6.addControl(mini_map_bf64a54f1afb5ecac53d25bb987df0f1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coordinates = [
[56.95080,24.11650],
[56.9506724,24.11533],
[56.9515315,24.1143683],
[56.9518371,24.1138815],
[56.9515036,24.1135815]]

centrs = folium.Map(location=[56.9514934,24.1135],
                        zoom_start = 17)

path = folium.PolyLine(
    [coordinates]
).add_to(centrs)

# Create the map and add the line
folium.Marker([56.95080,24.11650], popup='Latvijas universitāte', icon=folium.Icon(color='red')).add_to(centrs)
folium.Marker([56.9514934,24.1135],
              popup='Brīvības piemineklis',
              icon=folium.Icon(color='red')
             ).add_to(centrs)


plugins.PolyLineTextPath(
    path,
    'Uz brīvības pieminekli',
    offset=-5
).add_to(centrs)

centrs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e96a9fc351677776fda14a6825e93b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e96a9fc351677776fda14a6825e93b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e96a9fc351677776fda14a6825e93b1 = L.map(
#                 &quot;map_0e96a9fc351677776fda14a6825e93b1&quot;,
#                 {
#                     center: [56.9514934, 24.1135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bae9509ba0d56d38051289157923560f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e96a9fc351677776fda14a6825e93b1);
#
#
#             var poly_line_b4ccdc528c21da883df7d16103097f67 = L.polyline(
#                 [[[56.9508, 24.1165], [56.9506724, 24.11533], [56.9515315, 24.1143683], [56.9518371, 24.1138815], [56.9515036, 24.1135815]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e96a9fc351677776fda14a6825e93b1);
#
#
#             var marker_527639038a74cf555c0bbc7d936eb2d6 = L.marker(
#                 [56.9508, 24.1165],
#                 {}
#             ).addTo(map_0e96a9fc351677776fda14a6825e93b1);
#
#
#             var icon_b52045e7562d5bb02bb0024af9aef53a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_527639038a74cf555c0bbc7d936eb2d6.setIcon(icon_b52045e7562d5bb02bb0024af9aef53a);
#
#
#         var popup_0ced54240bbfd047b65ad6ddc25eb33d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77ae2d062334c1df4fac41197892d601 = $(`&lt;div id=&quot;html_77ae2d062334c1df4fac41197892d601&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latvijas universitāte&lt;/div&gt;`)[0];
#                 popup_0ced54240bbfd047b65ad6ddc25eb33d.setContent(html_77ae2d062334c1df4fac41197892d601);
#
#
#
#         marker_527639038a74cf555c0bbc7d936eb2d6.bindPopup(popup_0ced54240bbfd047b65ad6ddc25eb33d)
#         ;
#
#
#
#
#             var marker_24a249ca473e8b7fcb71cc441c070f58 = L.marker(
#                 [56.9514934, 24.1135],
#                 {}
#             ).addTo(map_0e96a9fc351677776fda14a6825e93b1);
#
#
#             var icon_d275b4ddaaa2367b932dffe9030b154f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_24a249ca473e8b7fcb71cc441c070f58.setIcon(icon_d275b4ddaaa2367b932dffe9030b154f);
#
#
#         var popup_d0acc4b6e2be2e22e1ef5779ba212327 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93867b6179efdeffe45e693d72f7d50e = $(`&lt;div id=&quot;html_93867b6179efdeffe45e693d72f7d50e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brīvības piemineklis&lt;/div&gt;`)[0];
#                 popup_d0acc4b6e2be2e22e1ef5779ba212327.setContent(html_93867b6179efdeffe45e693d72f7d50e);
#
#
#
#         marker_24a249ca473e8b7fcb71cc441c070f58.bindPopup(popup_d0acc4b6e2be2e22e1ef5779ba212327)
#         ;
#
#
#
#
#             poly_line_b4ccdc528c21da883df7d16103097f67.setText(
#                 &quot;Uz br\u012bv\u012bbas pieminekli&quot;,
#                 {&quot;below&quot;: false, &quot;center&quot;: false, &quot;offset&quot;: -5, &quot;orientation&quot;: 0, &quot;repeat&quot;: false}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#https://www.openstreetmap.org/relation/1554509
#http://polygons.openstreetmap.fr/
riga = os.path.join('riga.json')
geo_json_data = json.load(open(riga))

# %%
riga = folium.Map(location=[56.9514934,24.1135],
                        zoom_start = 10)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        'fillColor': 'blue',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(riga)

riga.save(os.path.join('Colormaps_0.html')) #saglabā rezultātu html failā
riga
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e7f695546e93c4795214d9daae6d5ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e7f695546e93c4795214d9daae6d5ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e7f695546e93c4795214d9daae6d5ed = L.map(
#                 &quot;map_9e7f695546e93c4795214d9daae6d5ed&quot;,
#                 {
#                     center: [56.9514934, 24.1135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_822129d0bf452495cf787349a27d7ff9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e7f695546e93c4795214d9daae6d5ed);
#
#
#         function geo_json_7feeea48e6ed30bec353f85920af8a09_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_7feeea48e6ed30bec353f85920af8a09_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7feeea48e6ed30bec353f85920af8a09 = L.geoJson(null, {
#                 onEachFeature: geo_json_7feeea48e6ed30bec353f85920af8a09_onEachFeature,
#
#                 style: geo_json_7feeea48e6ed30bec353f85920af8a09_styler,
#         });
#
#         function geo_json_7feeea48e6ed30bec353f85920af8a09_add (data) {
#             geo_json_7feeea48e6ed30bec353f85920af8a09
#                 .addData(data)
#                 .addTo(map_9e7f695546e93c4795214d9daae6d5ed);
#         }
#             geo_json_7feeea48e6ed30bec353f85920af8a09_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;geometries&quot;: [{&quot;coordinates&quot;: [[[[23.9323704, 57.0088701], [23.9333454, 57.0097246], [23.9336425, 57.0098834], [23.934583, 57.0103859], [23.9357981, 57.0116981], [23.9376562, 57.012264], [23.9457351, 57.0147242], [23.9591597, 57.0188603], [23.9715609, 57.023708], [23.980833, 57.0282812], [23.9863771, 57.0311774], [23.9889452, 57.0330828], [23.990034, 57.0338905], [23.9914262, 57.0347591], [23.9978706, 57.0387788], [24.0007828, 57.0409034], [24.0022626, 57.0418538], [24.0062484, 57.0453034], [24.0103436, 57.0487162], [24.0143607, 57.0519572], [24.0176299, 57.0545112], [24.0191281, 57.0560838], [24.019729, 57.0567384], [24.0202929, 57.0574024], [24.02049, 57.0577431], [24.0206625, 57.0580677], [24.0208545, 57.0582528], [24.0209777, 57.0585292], [24.0211798, 57.0589048], [24.02118, 57.0593099], [24.0211424, 57.0593984], [24.0204898, 57.0598086], [24.0203985, 57.0598181], [24.0203987, 57.0599006], [24.0205922, 57.0602031], [24.0189662, 57.0609712], [24.0185206, 57.0611218], [24.0182515, 57.0613012], [24.0174412, 57.0616793], [24.0171348, 57.0617678], [24.0169175, 57.0619533], [24.0167277, 57.0620183], [24.0157081, 57.0625205], [24.015319, 57.0626688], [24.0151665, 57.0626975], [24.0149993, 57.062834], [24.0146073, 57.0630159], [24.0143198, 57.0631659], [24.0133558, 57.0635767], [24.0131354, 57.0636177], [24.0128687, 57.0638062], [24.0127335, 57.0639475], [24.0123204, 57.0641413], [24.0120103, 57.064287], [24.0117024, 57.0644317], [24.0114357, 57.0645945], [24.0112503, 57.0647132], [24.0110649, 57.064832], [24.0107954, 57.0650038], [24.0105258, 57.0651755], [24.0104956, 57.0651972], [24.0104013, 57.0652489], [24.0103557, 57.0652438], [24.0101299, 57.0653637], [24.0102495, 57.0654665], [24.0102951, 57.0654895], [24.0125187, 57.0669409], [24.0145774, 57.0682845], [24.0146748, 57.0684581], [24.0156131, 57.0682948], [24.0157185, 57.0682663], [24.0156868, 57.0682117], [24.0176413, 57.0678698], [24.0208131, 57.0672085], [24.0228392, 57.0666632], [24.0232562, 57.0665395], [24.0240601, 57.0663531], [24.0249726, 57.0660062], [24.0267846, 57.0654029], [24.0281647, 57.0648473], [24.0290611, 57.0644994], [24.0299467, 57.0645288], [24.0320271, 57.0652408], [24.0353534, 57.0661849], [24.0375285, 57.0668567], [24.0384399, 57.0668715], [24.0401692, 57.067349], [24.0430239, 57.0679608], [24.0450414, 57.0682762], [24.049255, 57.0692516], [24.0521372, 57.0694904], [24.0606604, 57.0710981], [24.0634052, 57.0713631], [24.0705215, 57.0727905], [24.0731503, 57.0731856], [24.0759861, 57.0737496], [24.0831454, 57.0755405], [24.0892811, 57.0769833], [24.0923129, 57.0777298], [24.0954594, 57.07873], [24.1033899, 57.0812275], [24.1070165, 57.0822494], [24.1109297, 57.0834623], [24.1122399, 57.08382], [24.1128546, 57.0840303], [24.1145299, 57.08464], [24.1190048, 57.0859815], [24.1194498, 57.0854018], [24.1198607, 57.0848611], [24.1199384, 57.0847585], [24.1211155, 57.0830976], [24.1178903, 57.0819644], [24.1172114, 57.0817211], [24.1169605, 57.0816324], [24.1174464, 57.0812

# %%
m = folium.Map([30, 0], zoom_start=3)

wind_locations = [
    [59.35560, -31.992190],
    [55.178870, -42.89062],
    [47.754100, -43.94531],
    [38.272690, -37.96875],
    [27.059130, -41.13281],
    [16.299050, -36.56250],
    [8.4071700, -30.23437],
    [1.0546300, -22.50000],
    [-8.754790, -18.28125],
    [-21.61658, -20.03906],
    [-31.35364, -24.25781],
    [-39.90974, -30.93750],
    [-43.83453, -41.13281],
    [-47.75410, -49.92187],
    [-50.95843, -54.14062],
    [-55.97380, -56.60156]
]

wind_line = folium.PolyLine(
    wind_locations,
    weight=15,
    color='#8EE9FF'
).add_to(m)

attr = {'fill': '#007DEF', 'font-weight': 'bold', 'font-size': '24'}

plugins.PolyLineTextPath(
    wind_line,
    ') ',
    repeat=True,
    offset=7,
    attributes=attr
).add_to(m)

danger_line = folium.PolyLine(
    [[-40.311, -31.952],
     [-12.086, -18.727]],
    weight=10,
    color='orange',
    opacity=0.8
).add_to(m)

attr = {'fill': 'red'}

plugins.PolyLineTextPath(
    danger_line,
    '\u25BA',
    repeat=True,
    offset=6,
    attributes=attr
).add_to(m)

plane_line = folium.PolyLine(
    [[-49.38237, -37.26562],
     [-1.75754, -14.41406],
     [51.61802, -23.20312]],
    weight=1,
    color='black'
).add_to(m)

attr = {'font-weight': 'bold', 'font-size': '24'}

plugins.PolyLineTextPath(
    plane_line,
    '\u2708     ',
    repeat=True,
    offset=8,
    attributes=attr
).add_to(m)


line_to_new_delhi = folium.PolyLine(
    [[46.67959447, 3.33984375],
     [46.5588603, 29.53125],
     [42.29356419, 51.328125],
     [35.74651226, 68.5546875],
     [28.65203063, 76.81640625]]
).add_to(m)


line_to_hanoi = folium.PolyLine(
    [[28.76765911, 77.60742188],
     [27.83907609, 88.72558594],
     [25.68113734, 97.3828125],
     [21.24842224, 105.77636719]]
).add_to(m)


plugins.PolyLineTextPath(
    line_to_new_delhi,
    'To New Delhi',
    offset=-5
).add_to(m)


plugins.PolyLineTextPath(
    line_to_hanoi,
    'To Hanoi',
    offset=-5
).add_to(m)

m.save(os.path.join('Polyline_text_path.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d63bd54b14bf71b2f8db3b50efec0884 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d63bd54b14bf71b2f8db3b50efec0884&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d63bd54b14bf71b2f8db3b50efec0884 = L.map(
#                 &quot;map_d63bd54b14bf71b2f8db3b50efec0884&quot;,
#                 {
#                     center: [30.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b44faff4040620643decbcfea3f9af13 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d63bd54b14bf71b2f8db3b50efec0884);
#
#
#             var poly_line_5d3ebdcad2a985d2cb6225fb1a89a00c = L.polyline(
#                 [[59.3556, -31.99219], [55.17887, -42.89062], [47.7541, -43.94531], [38.27269, -37.96875], [27.05913, -41.13281], [16.29905, -36.5625], [8.40717, -30.23437], [1.05463, -22.5], [-8.75479, -18.28125], [-21.61658, -20.03906], [-31.35364, -24.25781], [-39.90974, -30.9375], [-43.83453, -41.13281], [-47.7541, -49.92187], [-50.95843, -54.14062], [-55.9738, -56.60156]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8EE9FF&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#8EE9FF&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 15}
#             ).addTo(map_d63bd54b14bf71b2f8db3b50efec0884);
#
#
#             poly_line_5d3ebdcad2a985d2cb6225fb1a89a00c.setText(
#                 &quot;) &quot;,
#                 {&quot;attributes&quot;: {&quot;fill&quot;: &quot;#007DEF&quot;, &quot;font-size&quot;: &quot;24&quot;, &quot;font-weight&quot;: &quot;bold&quot;}, &quot;below&quot;: false, &quot;center&quot;: false, &quot;offset&quot;: 7, &quot;orientation&quot;: 0, &quot;repeat&quot;: true}
#             );
#
#
#             var poly_line_b49c0af8824d798c02f70818debaeba0 = L.polyline(
#                 [[-40.311, -31.952], [-12.086, -18.727]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_d63bd54b14bf71b2f8db3b50efec0884);
#
#
#             poly_line_b49c0af8824d798c02f70818debaeba0.setText(
#                 &quot;\u25ba&quot;,
#                 {&quot;attributes&quot;: {&quot;fill&quot;: &quot;red&quot;}, &quot;below&quot;: false, &quot;center&quot;: false, &quot;offset&quot;: 6, &quot;orientation&quot;: 0, &quot;repeat&quot;: true}
#             );
#
#
#             var poly_line_8210d347acef22b410eeaf7373f8ee2b = L.polyline(
#                 [[-49.38237, -37.26562], [-1.75754, -14.41406], [51.61802, -23.20312]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_d63bd54b14bf71b2f8db3b50efec0884);
#
#
#             poly_line_8210d347acef22b410eeaf7373f8ee2b.setText(
#                 &quot;\u2708     &quot;,
#                 {&quot;attributes&quot;: {&quot;font-size&quot;: &quot;24&quot;, &quot;font-weight&quot;: &quot;bold&quot;}, &quot;below&quot;: false, &quot;center&quot;: false, &quot;offset&quot;: 8, &quot;orientation&quot;: 0, &quot;repeat&quot;: true}
#             );
#
#
#             var poly_line_e30dc517455f3e0db98237c1fcd0b2c0 = L.polyline(
#                 [[46.67959447, 3.33984375], [46.5588603, 29.53125], [42.29356419, 51.328125], [35.74651226, 68.5546875], [28.65203063, 76.81640625]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashAr

# %%
us_states = os.path.join('us-states.json')
geo_json_data = json.load(open(us_states))

unemployment = pd.read_csv('US_Unemployment_Oct2012.csv')

unemployment_dict = unemployment.set_index('State')['Unemployment']

# %%
def my_color_function(feature):
    "Zemās vērtības - zaļas. Augstās - sarkanas"
    if unemployment_dict[feature['id']] > 6.5:
        return '#ff0000'
    else:
        return '#008000'

# %%
m = folium.Map([43, -100], tiles='cartodbpositron', zoom_start=4)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        'fillColor': my_color_function(feature),
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

m.save(os.path.join('Colormaps_1.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24dfb2774cd630a14da6c82e03337c87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24dfb2774cd630a14da6c82e03337c87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24dfb2774cd630a14da6c82e03337c87 = L.map(
#                 &quot;map_24dfb2774cd630a14da6c82e03337c87&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab775f6776e698eefbd0ba9181396706 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24dfb2774cd630a14da6c82e03337c87);
#
#
#         function geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04_styler(feature) {
#             switch(feature.id) {
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MN&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;ND&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#008000&quot;, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04 = L.geoJson(null, {
#                 onEachFeature: geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04_onEachFeature,
#
#                 style: geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04_styler,
#         });
#
#         function geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04_add (data) {
#             geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04
#                 .addData(data)
#                 .addTo(map_24dfb2774cd630a14da6c82e03337c87);
#         }
#             geo_json_e34bbfc2d5cc181edc0e8bb8bfbebd04_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469], [-131.645836, 55.304197], [-131.749898, 55.128935], [-131.832052, 55.189182], [-131.832052, 55.42469]]], [[[-132.976733, 56.437924], [-132.735747, 56.459832], [-132.631685, 56.421493], [-132.664547, 56.273616], [-132.878148, 56.240754], [-133.069841, 56.333862], [-132.976733, 56.437924]]], [[[-133.595627, 56.350293], [-133.162949, 56.317431], [-133.05341, 56.125739], [-132.620732, 55.912138], [-132.472854, 55.780691], [-132.4619, 55.671152], [-132.357838, 55.649245], [-132.341408, 55.506844], [-132.166146, 55.364444], [-132.144238, 55.238474], [-132.029222, 55.276813], [-131.97993, 55.178228], [-131.958022, 54.789365], [-132.029222, 54.701734], [-132.308546, 54.718165], [-132.385223, 54.915335], [-132.483808, 54.898904], [-132.686455, 55.046781], [-132.746701, 54.997489], [-132.916486, 55.046781], [-132.889102, 54.898904], [-132.73027, 54.937242], [-132.626209, 54.882473], [-132.675501, 54.679826], [-132.867194, 54.701734], [-133.157472, 54.95915], [-133.239626, 55.090597], [-133.223195, 55.22752], [-133.453227, 55.216566], [-133.453227, 55.320628

# %%
import branca.colormap as cm

linear = cm.LinearColormap(
    ['green', 'yellow', 'red'],
    vmin=3, vmax=10
)

linear
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#018100ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#028100ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#038200ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#048200ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#058300ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#068300ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#078400ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#098500ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#0a8500ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#0b8600ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#0c8600ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#0d8700ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#0e8700ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#0f8800ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#118900ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#128900ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#138a00ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#148a00ff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#158b00ff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#168b00ff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#178c00ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#198c00ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#1a8d00ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#1b8e00ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#1c8e00ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#1d8f00ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#1e8f00ff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#1f9000ff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#219000ff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#229100ff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#239200ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#249200ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#259300ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#269300ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#279400ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#299400ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#2a9500ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#2b9600ff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#2c9600ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#2d9700ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#2e9700ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#2f9800ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#319800ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#329900ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#339a00ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#349a00ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#359b00ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#369b00ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %%
m = folium.Map([43, -100], tiles='cartodbpositron', zoom_start=4)

folium.GeoJson(
    geo_json_data,
    style_function=lambda feature: {
        'fillColor': linear(unemployment_dict[feature['id']]),
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

m.save(os.path.join('Colormaps_2.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46c79ea3394b8cdf803559cf1613f937 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46c79ea3394b8cdf803559cf1613f937&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46c79ea3394b8cdf803559cf1613f937 = L.map(
#                 &quot;map_46c79ea3394b8cdf803559cf1613f937&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0e112233bdae647cf101efe530008ad = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46c79ea3394b8cdf803559cf1613f937);
#
#
#         function geo_json_76ecbeeef55f7294fd1668259b012eb2_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;DE&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ffd400ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;AZ&quot;: case &quot;KY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff8a00ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;AR&quot;: case &quot;ME&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ffcc00ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;CO&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ffa800ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;CT&quot;: case &quot;IN&quot;: case &quot;NY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff7500ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;FL&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff8300ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;GA&quot;: case &quot;IL&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff5700ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;HI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#afd700ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;ID&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#fff800ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;IA&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#99cd00ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;KS&quot;: case &quot;MN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#bedf00ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;LA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#d4ea00ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;MA&quot;: case &quot;MO&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#fff100ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;MI&quot;: case &quot;MS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ff4100ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;MT&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#cce600ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;NE&quot;:
#                     return {&quot;col
